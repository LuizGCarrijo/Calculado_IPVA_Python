# %%
#Integrantes-------------------------------------------------------------------------------- Leonardo Bonvechio & Luiz Carrijo
print("Calculadora de IPVA:")

estadoOrigem = int(input("Qual a região do seu veículo? 1-(SP) 2-(RJ) 3-(ES) 4-(MG)"))
while estadoOrigem >4 or estadoOrigem <=0:
    estadoOrigem = int(input("Qual a região do seu veículo? 1-(SP) 2-(RJ) 3-(ES) 4-(MG)"))
#------------------------------------------------------------------------------------------- While para não deixar passar valor inválido
tipoVeiculo = int(input("Qual o tipo do seu veículo? 1-(Carro) 2-(Moto) 3-(Caminhão)"))
while tipoVeiculo >3 or tipoVeiculo <=0:
    tipoVeiculo = int(input("Qual o tipo do seu veículo? 1-(Carro) 2-(Moto) 3-(Caminhão)"))
#------------------------------------------------------------------------------------------- While para não deixar passar valor inválido
valorVeiculo = float(input("Digite o valor do seu veículo:"))

#IPVA -------------------------------------------------------------------------------------- IPVA SP carro, moto, caminhão
if estadoOrigem == 1:
    print("Estado escolhido São Paulo")
    if tipoVeiculo ==1:
        print("Veículo escolhido carro")
        print("O valor do seu IPVA é de R$", round(valorVeiculo * 0.04, 2))
        formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        while formaPagamento >=3 or formaPagamento <=0:
            formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        if formaPagamento == 1:
            print("Forma de pagamento escolhida À vista")
            print("O desconto do IPVA à vista é de R$:", round(valorVeiculo * 0.04 * 0.05, 2))
            print("Com isso o IPVA ficou no valor de R$:", round (valorVeiculo * 0.04 * 0.95, 2))
        elif formaPagamento == 2:
            print("Forma de pagamento escolhida Parcelado")
            print("Seu IPVA pode ser parcelado em até 6x de RS:", round(valorVeiculo * 0.04 / 6, 2))

    elif tipoVeiculo == 2:
        print("Veículo escolhido moto")
        print("O valor do seu IPVA é de R$", round(valorVeiculo * 0.02, 2))
        formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        while formaPagamento >=3 or formaPagamento <=0:
            formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        if formaPagamento == 1:
            print("Forma de pagamento escolhida À vista")
            print("O desconto do IPVA à vista é de R$:", round(valorVeiculo * 0.02 * 0.05, 2))
            print("Com isso o IPVA ficou no valor de R$:", round (valorVeiculo * 0.02 * 0.95, 2))
        elif formaPagamento == 2:
            print("Forma de pagamento escolhida Parcelado")
            print("Seu IPVA pode ser parcelado em até 6x de RS:", round(valorVeiculo *0.02 / 6, 2))
    
    elif tipoVeiculo == 3:
        print("Veículo escolhido caminhão")
        print("O valor do seu IPVA é de R$:", round(valorVeiculo * 0.015, 2))
        formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        while formaPagamento >=3 or formaPagamento <=0:
            formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        if formaPagamento == 1:
            print("Forma de pagamento escolhida À vista")
            print("O desconto do IPVA à vista é de R$:", round(valorVeiculo * 0.015 * 0.05, 2))
            print("Com isso o IPVA ficou no valor de R$:", round (valorVeiculo * 0.015 * 0.95, 2))
        elif formaPagamento == 2:
            print("Forma de pagamento escolhida Parcelado")
            print("Seu IPVA pode ser parcelado em até 6x de RS:", round(valorVeiculo * 0.015 / 6, 2))
#IPVA -------------------------------------------------------------------------------------- IPVA SP carro, moto, caminhão
            
#IPVA -------------------------------------------------------------------------------------- IPVA RJ carro, moto, caminhão
elif estadoOrigem == 2:
    if tipoVeiculo == 1:
        print("Veículo escolhido carro")
        print("O valor do seu IPVA é de R$", round(valorVeiculo * 0.041, 2))
        formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        while formaPagamento >=3 or formaPagamento <=0:
            formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        if formaPagamento == 1:
            print("Forma de pagamento escolhida À vista")
            print("O desconto do IPVA à vista é de R$:", round(valorVeiculo * 0.041 * 0.05, 2))
            print("Com isso o IPVA ficou no valor de R$:", round (valorVeiculo * 0.041 * 0.95, 2))
        elif formaPagamento == 2:
            print("Forma de pagamento escolhida Parcelado")
            print("Seu IPVA pode ser parcelado em até 6x de RS:", round(valorVeiculo * 0.041 / 6, 2))
    
    elif tipoVeiculo == 2:
        print("Veículo escolhido moto")
        print("O valor do seu IPVA é de R$", round(valorVeiculo * 0.025, 2))
        formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        while formaPagamento >=3 or formaPagamento <=0:
            formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        if formaPagamento == 1:
            print("Forma de pagamento escolhida À vista")
            print("O desconto do IPVA à vista é de R$:", round(valorVeiculo * 0.025 * 0.05, 2))
            print("Com isso o IPVA ficou no valor de R$:", round (valorVeiculo * 0.025 * 0.95, 2))
        elif formaPagamento == 2:
            print("Forma de pagamento escolhida Parcelado")
            print("Seu IPVA pode ser parcelado em até 6x de RS:", round(valorVeiculo * 0.025 / 6, 2))

    elif tipoVeiculo == 3:
        print("Veículo escolhido caminhão")
        print("O valor do seu IPVA é de R$", round(valorVeiculo * 0.013, 2))
        formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        while formaPagamento >=3 or formaPagamento <=0:
            formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        if formaPagamento == 1:
            print("Forma de pagamento escolhida À vista")
            print("O desconto do IPVA à vista é de R$:", round(valorVeiculo * 0.013 * 0.05, 2))
            print("Com isso o IPVA ficou no valor de R$:", round (valorVeiculo * 0.013 * 0.95, 2))
        elif formaPagamento == 2:
            print("Forma de pagamento escolhida Parcelado")
            print("Seu IPVA pode ser parcelado em até 6x de RS:", round(valorVeiculo * 0.013 / 6, 2))
#IPVA -------------------------------------------------------------------------------------- IPVA RJ carro, moto, caminhão
            
#IPVA -------------------------------------------------------------------------------------- IPVA ES carro, moto, caminhão
elif estadoOrigem == 3:
    if tipoVeiculo == 1:
        print("Veículo escolhido carro")
        print("O valor do seu IPVA é de R$", round(valorVeiculo * 0.02, 2))
        formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        while formaPagamento >=3 or formaPagamento <=0:
            formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        if formaPagamento == 1:
            print("Forma de pagamento escolhida À vista")
            print("O desconto do IPVA à vista é de R$:", round(valorVeiculo * 0.02 * 0.05, 2))
            print("Com isso o IPVA ficou no valor de R$:", round (valorVeiculo * 0.02 * 0.95, 2))
        elif formaPagamento == 2:
            print("Forma de pagamento escolhida Parcelado")
            print("Seu IPVA pode ser parcelado em até 6x de RS:", round(valorVeiculo * 0.02 / 6, 2))

    elif tipoVeiculo == 2:
        print("Veículo escolhido moto")
        print("O valor do seu IPVA é de R$", round(valorVeiculo * 0.0175, 2))
        formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        while formaPagamento >=3 or formaPagamento <=0:
            formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        if formaPagamento == 1:
            print("Forma de pagamento escolhida À vista")
            print("O desconto do IPVA à vista é de R$:", round(valorVeiculo * 0.0175 * 0.05, 2))
            print("Com isso o IPVA ficou no valor de R$:", round (valorVeiculo * 0.0175 * 0.95, 2))
        elif formaPagamento == 2:
            print("Forma de pagamento escolhida Parcelado")
            print("Seu IPVA pode ser parcelado em até 6x de RS:", round(valorVeiculo * 0.0175 / 6, 2))
    
    elif tipoVeiculo == 3:
        print("Veículo escolhido caminhão")
        print("O valor do seu IPVA é de R$", round(valorVeiculo * 0.03, 2))
        formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        while formaPagamento >=3 or formaPagamento <=0:
            formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        if formaPagamento == 1:
            print("Forma de pagamento escolhida À vista")
            print("O desconto do IPVA à vista é de R$:", round(valorVeiculo * 0.03 * 0.05, 2))
            print("Com isso o IPVA ficou no valor de R$:", round (valorVeiculo * 0.03 * 0.95, 2))
        elif formaPagamento == 2:
            print("Forma de pagamento escolhida Parcelado")
            print("Seu IPVA pode ser parcelado em até 6x de RS:", round(valorVeiculo * 0.03 / 6, 2))
#IPVA -------------------------------------------------------------------------------------- IPVA ES carro, moto, caminhão
            
#IPVA -------------------------------------------------------------------------------------- IPVA MG carro, moto, caminhão
elif estadoOrigem == 4:
    if tipoVeiculo ==1:
        print("Veículo escolhido carro")
        print("O valor do seu IPVA é de R$", round(valorVeiculo * 0.042, 2))
        formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        while formaPagamento >=3 or formaPagamento <=0:
            formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        if formaPagamento == 1:
            print("Forma de pagamento escolhida À vista")
            print("O desconto do IPVA à vista é de R$:", round(valorVeiculo * 0.042 * 0.05, 2))
            print("Com isso o IPVA ficou no valor de R$:", round (valorVeiculo * 0.042 * 0.95, 2))
        elif formaPagamento == 2:
            print("Forma de pagamento escolhida Parcelado")
            print("Seu IPVA pode ser parcelado em até 6x de RS:", round(valorVeiculo * 0.042 / 6, 2))

    elif tipoVeiculo == 2:
        print("Veículo escolhido moto")
        print("O valor do seu IPVA é de R$", round(valorVeiculo * 0.022, 2))
        formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        while formaPagamento >=3 or formaPagamento <=0:
            formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        if formaPagamento == 1:
            print("Forma de pagamento escolhida À vista")
            print("O desconto do IPVA à vista é de R$:", round(valorVeiculo * 0.022 * 0.05, 2))
            print("Com isso o IPVA ficou no valor de R$:", round (valorVeiculo * 0.022 * 0.95, 2))
        elif formaPagamento == 2:
            print("Forma de pagamento escolhida Parcelado")
            print("Seu IPVA pode ser parcelado em até 6x de RS:", round(valorVeiculo * 0.022 / 6, 2))

    elif tipoVeiculo == 3:
        print("Veículo escolhido caminhão")
        print("O valor do seu IPVA é de R$", round(valorVeiculo * 0.01, 2))
        formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        while formaPagamento >=3 or formaPagamento <=0:
            formaPagamento = int(input("Qual será a forma de pagamento? 1-(À vista) 2-(Parcelado)"))
        if formaPagamento == 1:
            print("Forma de pagamento escolhida À vista")
            print("O desconto do IPVA à vista é de R$:", round(valorVeiculo * 0.01 * 0.05, 2))
            print("Com isso o IPVA ficou no valor de R$:", round (valorVeiculo * 0.01 * 0.95, 2))
        elif formaPagamento == 2:
            print("Forma de pagamento escolhida Parcelado")
            print("Seu IPVA pode ser parcelado em até 6x de RS:", round(valorVeiculo * 0.01 / 6, 2))
#IPVA -------------------------------------------------------------------------------------- IPVA MG carro, moto, caminhão
# Out:
# Calculadora de IPVA:
# Estado escolhido São Paulo
# Veículo escolhido carro
# O valor do seu IPVA é de R$ 852.12
# Forma de pagamento escolhida À vista
# O desconto do IPVA à vista é de R$: 42.61
# Com isso o IPVA ficou no valor de R$: 809.51
